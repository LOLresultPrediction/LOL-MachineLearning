# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy

# %%
tier = 'IRON'
df = pd.read_csv(f'../Dataset/perMinuteDataset/result/event/{tier}.csv')
result = pd.read_csv(f'../Dataset/perMinuteDataset/result/accuracy/{tier}.csv')

# %%
df_transposed = df.transpose()
df_transposed.columns = df_transposed.iloc[0]

df_transposed = df_transposed[1:]
df_transposed
# Out:
# MatchId KR_6790213174 KR_6747251823 KR_6776134083 KR_6693583553 KR_6774991110  \
# 5min               43            28            20            36            39
# 6min               47            29            38            22            28
# 7min               44            38            21            23            35
# 8min               53            29            38            32            35
# 9min               49            22            63            32            35
# 10min              52            35            39            35            34
# 11min              61            30            42            55            38
# 12min              26            31            24            37            41
# 13min              72            44            60            45            31
# 14min              70            26            33            35            40
# 15min              44            33            44            59            27
#
# MatchId KR_6505078150 KR_6612840944 KR_6697852848 KR_6752166562 KR_6788497781  \
# 5min               34            26            35            34            32
# 6min               29            30            33            40            32
# 7min               44            31            30            39            28
# 8min               47            38            29            58            32
# 9min               38            32            23            33            29
# 10min              49            21            52            49            33
# 11min              24            35            35            52            33
# 12min              49            40            30            44            38
# 13min              48            29            49            33            24
# 14min              32            40            31            53            25
# 15min              27            43            56            31            28
#
# MatchId  ... KR_6724913638 KR_6500128379 KR_6602406328 KR_6751196549  \
# 5min     ...            39            40            35            35
# 6min     ...            24            32            27            30
# 7min     ...            26            29            25            31
# 8min     ...            35            34            22            14
# 9min     ...            25            24            29            42
# 10min    ...            52            31            15            27
# 11min    ...            34            33            28            34
# 12min    ...            20            28            37            37
# 13min    ...            48            47            38            29
# 14min    ...            29            32            30            35
# 15min    ...            34            34            25            16
#
# MatchId KR_6706194469 KR_6508237420 KR_6789247234 KR_6643339956 KR_6714205865  \
# 5min               29            41            30            39            23
# 6min               18            32            18            27            26
# 7min               39            34            48            37            29
# 8min               26            23            25            28            26
# 9min               24            31            24            33            37
# 10min              20            46            28            15            24
# 11min              46            27            40            43            33
# 12min              27            40            39            21            29
# 13min              23            42            28            27            31
# 14min              33            27            31            31            27
# 15min              31            40            40            45            32
#
# MatchId KR_6612220813
# 5min               42
# 6min               32
# 7min               24
# 8min               20
# 9min               37
# 10min              32
# 11min              25
# 12min              37
# 13min              36
# 14min              21
# 15min              44
#
# [11 rows x 1000 columns]

# %%
dfMean = df.iloc[:,1:].mean()
result2RandomForest = result[result['Model'] == 'RandomForest']
result2LightGBM = result[result['Model'] == 'LightGBM']
result2CatBoost = result[result['Model'] == 'CatBoost']
result2ExtraTrees = result[result['Model'] == 'ExtraTree']

plt.figure(figsize=(10, 6))
plt.plot(dfMean.index, dfMean.values*2, label='event', marker='o', linestyle='-', linewidth=5)
plt.plot(dfMean.index, result2RandomForest['accuracy_score'], label='RF_Accuracy', marker='o', linestyle='--')
plt.plot(dfMean.index, result2LightGBM['accuracy_score'], label='LGBM_Accuracy', marker='o', linestyle='--')
plt.plot(dfMean.index, result2CatBoost['accuracy_score'], label='CB_Accuracy', marker='o', linestyle='--')
plt.plot(dfMean.index, result2ExtraTrees['accuracy_score'], label='ET_Accuracy', marker='o', linestyle='--')
plt.title(tier)
plt.xlabel('분')
plt.ylabel('이벤트 발생 개수')
plt.legend()
plt.grid(True)
# 그래프 보여주기
plt.show()

# %%
# plt.bar(dfMean.index, dfMean, label='평균 및 표준편차', color='skyblue')
# # 그래프 스타일 설정
# plt.xlabel('데이터 컬럼')
# plt.ylabel('값')
# plt.legend()
# plt.grid(axis='y')

# # 그래프 보여주기
# plt.show()

# %%
# df_transposed.plot(marker='o', linestyle='-', figsize=(20, 10))
# plt.title('CHALLENGER')
# plt.xlabel('시간 (분)')
# plt.ylabel('이벤트 발생 수')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# # 그래프 표시
# plt.show()
